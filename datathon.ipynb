# %%
import torch 
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import csv

myseed = 10  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %%
data=pd.read_csv('random_sample.csv')

# %%
data.head()
# Out:
#                user_id            status_id            created_at  \
# 0           1060370282  1392106273223610379  2021-05-11T13:16:14Z
# 1   818554054309715969  1284947108827746305  2020-07-19T20:23:58Z
# 2            385429543   988119683831234560  2018-04-22T18:17:45Z
# 3  1080573351914061825  1184820381082968064  2019-10-17T13:16:06Z
# 4           1065995022   906239678013169664  2017-09-08T19:35:51Z
#
#      screen_name                                               text  \
# 0      RepMullin  📲 REMINDER: I will be hosting a Telephone Town...
# 1  SenJackyRosen  The best way the Senate can honor the legacy o...
# 2    RepMcNerney  Today, many of you will be celebrating #EarthD...
# 3  RepDavidTrone  Elijah Cummings was a voice for the powerless ...
# 4    RepWalorski  Learn about our #taxreform plan to help busine...
#
#                source  display_text_width  reply_to_status_id  \
# 0     Twitter Web App                 180                 NaN
# 1  Twitter for iPhone                 110                 NaN
# 2  Twitter for iPhone                 227                 NaN
# 3  Twitter for iPhone                 275                 NaN
# 4           TweetDeck                 145                 NaN
#
#    reply_to_user_id reply_to_screen_name  ...  statuses_count  \
# 0               NaN                  NaN  ...            4902
# 1               NaN                  NaN  ...            8870
# 2               NaN                  NaN  ...            2781
# 3               NaN                  NaN  ...            3987
# 4               NaN                  NaN  ...            6296
#
#    favourites_count    account_created_at  verified              profile_url  \
# 0              1388  2013-01-04T12:43:55Z      True  https://t.co/Qv5teppuYQ
# 1               611  2017-01-09T20:24:29Z      True  https://t.co/fq26igiB6n
# 2               593  2011-10-05T13:52:58Z      True  https://t.co/So4mXjTwdK
# 3               522  2019-01-02T21:15:37Z      True  https://t.co/ROC81aFsfE
# 4               702  2013-01-06T15:41:40Z      True   http://t.co/1c3JNm0kJ5
#
#           profile_expanded_url  account_lang  \
# 0  http://www.mullin.house.gov           NaN
# 1  http://www.rosen.senate.gov           NaN
# 2    http://mcnerney.house.gov           NaN
# 3      https://trone.house.gov           NaN
# 4    http://walorski.house.gov           NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/10603702...
# 1  https://pbs.twimg.com/profile_banners/81855405...
# 2  https://pbs.twimg.com/profile_banners/38542954...
# 3  https://pbs.twimg.com/profile_banners/10805733...
# 4  https://pbs.twimg.com/profile_banners/10659950...
#
#                              profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme1/bg.png
# 1                                               NaN
# 2  http://abs.twimg.com/images/themes/theme1/bg.png
# 3                                               NaN
# 4  http://abs.twimg.com/images/themes/theme1/bg.png
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/9366845588...
# 1  http://pbs.twimg.com/profile_images/1085182795...
# 2  http://pbs.twimg.com/profile_images/4536029670...
# 3  http://pbs.twimg.com/profile_images/1110578625...
# 4  http://pbs.twimg.com/profile_images/1352299062...
#
# [5 rows x 90 columns]

# %% [markdown]
# Preprocessing

# %%
Missing_Count=data.isnull().sum()

# %%
Missing_Count
# Out:
# user_id                       0
# status_id                     0
# created_at                    0
# screen_name                   0
# text                          0
#                           ...
# profile_expanded_url        891
# account_lang              25000
# profile_banner_url          187
# profile_background_url     5789
# profile_image_url             0
# Length: 90, dtype: int64

# %%
No_Missing=list(Missing_Count[Missing_Count==0].index)
All_Missing=list(Missing_Count[Missing_Count==25000].index)
Most_Missing=list(Missing_Count[Missing_Count>20000].index)
Low_Missing=list(Missing_Count[Missing_Count<10000].index)

# %%
Low_Missing
# Out:
# ['user_id',
#  'status_id',
#  'created_at',
#  'screen_name',
#  'text',
#  'source',
#  'display_text_width',
#  'is_quote',
#  'is_retweet',
#  'favorite_count',
#  'retweet_count',
#  'lang',
#  'status_url',
#  'name',
#  'location',
#  'description',
#  'url',
#  'protected',
#  'followers_count',
#  'friends_count',
#  'listed_count',
#  'statuses_count',
#  'favourites_count',
#  'account_created_at',
#  'verified',
#  'profile_url',
#  'profile_expanded_url',
#  'profile_banner_url',
#  'profile_background_url',
#  'profile_image_url']

# %%
data.loc[:,'profile_image_url']
# Out:
# 0        http://pbs.twimg.com/profile_images/9366845588...
# 1        http://pbs.twimg.com/profile_images/1085182795...
# 2        http://pbs.twimg.com/profile_images/4536029670...
# 3        http://pbs.twimg.com/profile_images/1110578625...
# 4        http://pbs.twimg.com/profile_images/1352299062...
#                                ...
# 24995    http://pbs.twimg.com/profile_images/9990132279...
# 24996    http://pbs.twimg.com/profile_images/1268034070...
# 24997    http://pbs.twimg.com/profile_images/1267871657...
# 24998    http://pbs.twimg.com/profile_images/1387224813...
# 24999    http://pbs.twimg.com/profile_images/9790454464...
# Name: profile_image_url, Length: 25000, dtype: object

# %%
# Out:
# reply_to_status_id        22449
# reply_to_user_id          22377
# reply_to_screen_name      22377
# quote_count               25000
# reply_count               25000
# hashtags                  25000
# symbols                   25000
# urls_url                  25000
# urls_t.co                 25000
# urls_expanded_url         25000
# media_url                 25000
# media_t.co                25000
# media_expanded_url        25000
# media_type                25000
# ext_media_url             25000
# ext_media_t.co            25000
# ext_media_expanded_url    25000
# ext_media_type            25000
# mentions_user_id          25000
# mentions_screen_name      25000
# quoted_status_id          22407
# quoted_text               22407
# quoted_created_at         22407
# quoted_source             22407
# quoted_favorite_count     22407
# quoted_retweet_count      22407
# quoted_user_id            22407
# quoted_screen_name        22407
# quoted_name               22407
# quoted_followers_count    22407
# quoted_friends_count      22407
# quoted_statuses_count     22407
# quoted_location           22758
# quoted_description        22426
# quoted_verified           22407
# retweet_location          20312
# place_url                 24790
# place_name                24790
# place_full_name           24790
# place_type                24790
# country                   24790
# country_code              24790
# geo_coords                25000
# coords_coords             25000
# bbox_coords               25000
# account_lang              25000
# dtype: int64
